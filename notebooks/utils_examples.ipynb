# %%
import sys
sys.path.append('../')

# %%
from src.utils.gotriple_data import get_gotriple_sample

samples = get_gotriple_sample(['en'], 10, query_terms_file='../data/query_terms.json')

# %%
from src.utils.wikidata_data import query_dbpedia_spotlight

# Example usage
text = "Barack Obama was born in Hawaii and was the 44th president of the United States."
result = query_dbpedia_spotlight(text, "en", 0.5)
